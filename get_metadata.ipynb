# %%
import pandas as pd
import numpy as np
import json
from PIL import Image

# %%
df = pd.read_excel('src/static/Shufu no tomo Metadata.xlsx')
df = df.drop([0, 1])

# %%
results = []
for i, row in df.iterrows():
    img = Image.open(f"src/static/{row['file name FRONT']}")
    
    append = {
        'src': row['file name FRONT'],
        'src_back': row['file name BACK'],
        'title_japanese': row['card title on front'],
        'title_english': row['card title on front in'],
        'width': img.size[0],
        'height': img.size[1],
        'year': row['date of card']
    }
    results.append(append)

# %%
results
# Out:
# [{'src': 'shufu.11.001.jpg',
#   'src_back': 'shufu.11.002.jpg',
#   'title_japanese': 'Tokyo Gekijo',
#   'title_english': 'Tokyo Theater',
#   'width': 4525,
#   'height': 2909,
#   'year': 1932.0},
#  {'src': 'shufu.12.001.jpg',
#   'src_back': 'shufu.12.002.jpg',
#   'title_japanese': 'Kabuki-za',
#   'title_english': 'Classical Kabuki Theater',
#   'width': 4542,
#   'height': 2879,
#   'year': 1932.0},
#  {'src': 'shufu.13.001.jpg',
#   'src_back': 'shufu.13.002.jpg',
#   'title_japanese': 'Otemachi Toori',
#   'title_english': 'Otemachi Street',
#   'width': 4498,
#   'height': 2851,
#   'year': 1932.0},
#  {'src': 'shufu.14.001.jpg',
#   'src_back': 'shufu.14.002.jpg',
#   'title_japanese': 'Tokyo Shiyakusho',
#   'title_english': 'Tokyo City Hall',
#   'width': 2899,
#   'height': 4497,
#   'year': 1932.0},
#  {'src': 'shufu.15.001.jpg',
#   'src_back': 'shufu.15.002.jpg',
#   'title_japanese': 'Ginza Owaricho',
#   'title_english': 'Ginza Owaricho District',
#   'width': 4440,
#   'height': 2869,
#   'year': 1932.0},
#  {'src': 'shufu.16.001.jpg',
#   'src_back': 'shufu.16.002.jpg',
#   'title_japanese': 'Mitsukoshi to Mitsui Ginko',
#   'title_english': 'Mistsukoshi and Mitsui Bank',
#   'width': 4456,
#   'height': 3005,
#   'year': 1932.0},
#  {'src': 'shufu.17.001.jpg',
#   'src_back': 'shufu.17.002.jpg',
#   'title_japanese': 'Chikatetsu Biru',
#   'title_english': 'Subway Building',
#   'width': 2913,
#   'height': 4500,
#   'year': 1932.0},
#  {'src': 'shufu.18.001.jpg',
#   'src_back': 'shufu.18.002.jpg',
#   'title_japanese': 'Keishicho',
#   'title_english': 'Police Station',
#   'width': 2886,
#   'height': 4497,
#   'year': 1932.0},
#  {'src': 'shufu.19.001.jpg',
#   'src_back': 'shufu.19.002.jpg',
#   'title_japanese': 'Maru Biru',
#   'title_english': 'Maru Building',
#   'width': 4557,
#   'height': 2911,
#   'year': 1932.0},
#  {'src': 'shufu.20.001.jpg',
#   'src_back': 'shufu.20.002.jpg',
#   'title_japanese': 'Nihon Bashi',
#   'title_english': 'Nihon Bridge',
#   'width': 4547,
#   'height': 2922,
#   'year': 1932.0},
#  {'src': 'shufu.21.001.jpg',
#   'src_back': 'shufu.21.002.jpg',
#   'title_japanese': 'Tokyo Chuo Denshinkyoku',
#   'title_english': 'Tokyo Central Telegraph Office',
#   'width': 2943,
#   'height': 4508,
#   'year': 1932.0},
#  {'src': 'shufu.22.001.jpg',
#   'src_back': 'shufu.22.002.jpg',
#   'title_japanese': 'Ginza Daitoori',
#   'title_english': 'Ginza Grand Street',
#   'width': 4507,
#   'height': 2985,
#   'year': 1932.0},
#  {'src': 'shufu.23.001.jpg',
#   'src_back': 'shufu.23.002.jpg',
#   'title_japanese': 'Tokyo Eki',
#   'title_english': 'Tokyo Station',
#   'width': 4499,
#   'height': 2890,
#   'year': 1932.0},
#  {'src': 'shufu.24.001.jpg',
#   'src_back': 'shufu.24.002.jpg',
#   'title_japanese': 'Yushukan',
#   'title_english': 'Yushukan',
#   'width': 4578,
#   'height': 2861,
#   'year': 1932.0},
#  {'src': 'shufu.25.001.jpg',
#   'src_back': 'shufu.25.002.jpg',
#   'title_japanese': 'Asakusa Denboin no niwa',
#   'title_english': 'The Garden of Asakusa Denboin',
#   'width': 4488,
#   'height': 2908,
#   'year': 1932.0},
#  {'src': 'shufu.26.001.jpg',
#   'src_back': 'shufu.26.002.jpg',
#   'title_japanese': 'Akasaka Benkei Bashi',
#   'title_english': 'Akasaka Benkei Bridge',
#   'width': 4534,
#   'height': 2949,
#   'year': 1932.0},
#  {'src': 'shufu.27.001.jpg',
#   'src_back': 'shufu.27.002.jpg',
#   'title_japanese': 'Ueno yamashita fukin',
#   'title_english': 'Near the foot of Mountain Ueno',
#   'width': 4545,
#   'height': 2875,
#   'year': 1932.0},
#  {'src': 'shufu.29.001.jpg',
#   'src_back': 'shufu.29.002.jpg',
#   'title_japanese': 'Sumida Kawa fukei',
#   'title_english': 'View of Sumida River',
#   'width': 4513,
#   'height': 2938,
#   'year': 1932.0},
#  {'src': 'shufu.30.001.jpg',
#   'src_back': 'shufu.30.002.jpg',
#   'title_japanese': 'Eidai Bashi',
#   'title_english': 'Eidai Bridge',
#   'width': 4561,
#   'height': 2957,
#   'year': 1932.0},
#  {'src': 'shufu.31.001.jpg',
#   'src_back': 'shufu.31.002.jpg',
#   'title_japanese': 'Nihon Ginko',
#   'title_english': 'Bank of Japan',
#   'width': 4540,
#   'height': 2942,
#   'year': 1932.0},
#  {'src': 'shufu.32.001.jpg',
#   'src_back': 'shufu.32.002.jpg',
#   'title_japanese': 'Shinjuku Eki',
#   'title_english': 'Shinjuku Station',
#   'width': 4595,
#   'height': 2913,
#   'year': 1932.0},
#  {'src': 'shufu.33.001.jpg',
#   'src_back': 'shufu.33.002.jpg',
#   'title_japanese': 'Ueno Eki',
#   'title_english': 'Ueno Station',
#   'width': 4498,
#   'height': 2886,
#   'year': 1932.0},
#  {'src': 'shufu.34.001.jpg',
#   'src_back': 'shufu.34.002.jpg',
#   'title_japanese': 'Tokyo-fu Bijutsukan',
#   'title_english': 'Tokyo Art Museum',
#   'width': 4571,
#   'height': 2916,
#   'year': 1932.0},
#  {'src': 'shufu.35.001.jpg',
#   'src_back': 'shufu.35.002.jpg',
#   'title_japanese': 'Tokyo Kagaku Hakubutsukan\u200b',
#   'title_english': 'Tokyo Science Museum',
#   'width': 4532,
#   'height': 2898,
#   'year': 1932.0},
#  {'src': 'shufu.36.001.jpg',
#   'src_back': 'shufu.36.002.jpg',
#   'title_japanese': 'Tokyo Chuo Yubinkyoku',
#   'title_english': 'Tokyo Central Post Office',
#   'width': 4535,
#   'height': 2886,
#   'year': 1932.0},
#  {'src': 'shufu.37.001.jpg',
#   'src_back': 'shufu.37.002.jpg',
#   'title_japanese': 'Nippon Seinenkan',
#   'title_english': 'Nippon Seinenkan',
#   'width': 4511,
#   'height': 2854,
#   'year': 1932.0},
#  {'src': 'shufu.38.001.jpg',
#   'src_back': 'shufu.38.002.jpg',
#   'title_japanese': 'Asakusa Koen Roku',
#   'title_english': 'Sixth District of Asakusa Park',
#   'width': 4479,
#   'height': 2941,
#   'year': 1932.0},
#  {'src': 'shufu.39.001.jpg',
#   'src_back': 'shufu.39.002.jpg',
#   'title_japanese': 'Birumachi no asa',
#   'title_english': 'Morning of Birumachi',
#   'width': 2869,
#   'height': 4519,
#   'year': 1932.0},
#  {'src': 'shufu.40.001.jpg',
#   'src_back': 'shufu.40.002.jpg',
#   'title_japanese': 'Babasenmon fukin',
#   'title_english': 'Near Babasenmon',
#   'width': 4522,
#   'height': 2943,
#   'year': 1932.0},
#  {'src': 'shufu.41.001.jpg',
#   'src_back': 'shufu.41.002.jpg',
#   'title_japanese': 'Jingu gaien',
#   'title_english': 'Outer gardens of Meiji Shrine\u200b',
#   'width': 4471,
#   'height': 2813,
#   'year': 1932.0},
#  {'src': 'shufu.42.001.jpg',
#   'src_back': 'shufu.42.002.jpg',
#   'title_japanese': 'Meiji Jingu Houmotsuden\u200b',
#   'title_english': 'Treasure House of Meiji Shrine',
#   'width': 2841,
#   'height': 4504,
#   'year': 1932.0},
#  {'src': 'shufu.43.001.jpg',
#   'src_back': 'shufu.43.002.jpg',
#   'title_japanese': 'Aoyama Gosho',
#   'title_english': 'Aoyama Imperial Palace',
#   'width': 4542,
#   'height': 2933,
#   'year': 1932.0},
#  {'src': 'shufu.44.001.jpg',
#   'src_back': 'shufu.44.002.jpg',
#   'title_japanese': 'Miyagi Ninomaru fukin',
#   'title_english': 'Near the outer citadel of Miyagi Palace',
#   'width': 4516,
#   'height': 2895,
#   'year': 1932.0},
#  {'src': 'shufu.45.001.jpg',
#   'src_back': 'shufu.45.002.jpg',
#   'title_japanese': 'Sengakuji sanmon',
#   'title_english': 'Main gate of Sengakuji Temple',
#   'width': 4542,
#   'height': 2883,
#   'year': 1932.0},
#  {'src': 'shufu.46.001.jpg',
#   'src_back': 'shufu.46.002.jpg',
#   'title_japanese': 'Shibaura no ganpeki',
#   'title_english': 'Port of Shibaura',
#   'width': 4534,
#   'height': 2894,
#   'year': 1932.0},
#  {'src': 'shufu.1001.jpg',
#   'src_back': 'shufu.1002.jpg',
#   'title_japanese': 'Nori wo toru fune',
#   'title_english': 'Boats to pick up seaweed',
#   'width': 4492,
#   'height': 2937,
#   'year': 1932.0},
#  {'src': 'shufu.2001.jpg',
#   'src_back': 'shufu.2002.jpg',
#   'title_japanese': 'Kanda Ichiba',
#   'title_english': 'Kanda Market',
#   'width': 2853,
#   'height': 4470,
#   'year': 1932.0},
#  {'src': 'shufu.3001.jpg',
#   'src_back': 'shufu.3002.jpg',
#   'title_japanese': 'Uogashi\u200b',
#   'title_english': 'Riverside fish market\u200b',
#   'width': 4438,
#   'height': 2834,
#   'year': 1932.0},
#  {'src': 'shufu.4001.jpg',
#   'src_back': 'shufu.4002.jpg',
#   'title_japanese': 'Mizu no ue no seikatsu',
#   'title_english': 'Life on the water',
#   'width': 4507,
#   'height': 2879,
#   'year': 1932.0},
#  {'src': 'shufu.5001.jpg',
#   'src_back': 'shufu.5002.jpg',
#   'title_japanese': 'Tokyo no hanmen',
#   'title_english': 'Backside of Tokyo',
#   'width': 4491,
#   'height': 2959,
#   'year': 1932.0},
#  {'src': 'shufu.6001.jpg',
#   'src_back': 'shufu.6002.jpg',
#   'title_japanese': 'Kasumigaseki toori',
#   'title_english': 'Kasumigaseki Street',
#   'width': 4492,
#   'height': 2867,
#   'year': 1932.0},
#  {'src': 'shufu.7001.jpg',
#   'src_back': 'shufu.7002.jpg',
#   'title_japanese': 'Sakurada mon',
#   'title_english': 'Sakurada Gate',
#   'width': 2935,
#   'height': 4525,
#   'year': 1932.0},
#  {'src': 'shufu.8001.jpg',
#   'src_back': 'shufu.8002.jpg',
#   'title_japanese': 'Ikegami Honmon-ji no Gojuutou\u200b',
#   'title_english': 'Five-storied Pagoda of Ikegami Honmon Temple',
#   'width': 2916,
#   'height': 4493,
#   'year': 1932.0},
#  {'src': 'shufu.9001.jpg',
#   'src_back': 'shufu.9002.jpg',
#   'title_japanese': 'Hibiya Koen',
#   'title_english': 'Hibiya Park',
#   'width': 4537,
#   'height': 2893,
#   'year': 1932.0},
#  {'src': 'shufu.10001.jpg',
#   'src_back': 'shufu.10002.jpg',
#   'title_japanese': 'Kiyosumi Teien',
#   'title_english': 'Kiyosumi Garden',
#   'width': 4467,
#   'height': 2908,
#   'year': 1932.0},
#  {'src': 'shufu.map002.jpg',
#   'src_back': 'shufu.map003.jpg',
#   'title_japanese': 'Dai Tokyo sanju-go ku',
#   'title_english': '35 Districts of Greater Tokyo',
#   'width': 3189,
#   'height': 4065,
#   'year': 1932.0}]

# %%
with open('./src/static/data.json', 'w') as f:
    json.dump(results, f)
